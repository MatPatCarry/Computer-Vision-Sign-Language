# %% [markdown]
# ### **Import needed libraries**

# %%
import json
import os
import cv2
import shutil
from skimage.transform import resize
from functools import partial
import tensorflow as tf
import keras
import numpy as np
import mediapipe as mp
from scipy.ndimage import gaussian_filter, median_filter, sobel
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.layers import (
    Resizing,
    Rescaling,
    Lambda,
    RandomFlip,
    RandomRotation,
    RandomZoom,
    RandomTranslation,
    MaxPooling2D,
    MaxPooling3D,
    Conv2D,
    ConvLSTM2D,
    Dense,
    Flatten,
    GlobalAveragePooling2D,
    Dropout, Input, TimeDistributed, LSTM, BatchNormalization, Activation
)
from matplotlib.image import imread
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle
from keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

import warnings
warnings.filterwarnings('ignore')

# %%
from functions_ml import refactor_video_into_input

# %%
tf.__version__
# Out:
# '2.8.3'

# %%
tf.random.set_seed(420)

# %%
IMAGE_SIZE = (256, 256)
SEQUENCE_LENGTH = 25
BG_COLOR = (255, 255, 255)

# %%
path_to_folder_with_videos =  "sign_language_videos"
path_to_folder_with_videos
# Out:
# 'sign_language_videos'

# %%
mp_selfie_segmentation = mp.solutions.selfie_segmentation
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %% [markdown]
# ### **Load json data about videos**

# %%
with open('videos_json_data.json', 'r') as f:
    data = json.load(f)

# %% [markdown]
# ### **Classes**

# %%
chosen_words = ['what', 'hello', 'love', 'please', 'thank you']

# %% [markdown]
# ### **Extract videos' needed indexes**

# %%
videos_indexes_dict = {}
for index, word_dict in enumerate(data):
    if word_dict['gloss'] in chosen_words:
        videos_indexes_dict[word_dict['gloss']] = [word_dict['instances'][i]['video_id'] for i in range(len(word_dict['instances']))]

# %%
videos_indexes_dict
# Out:
# {'what': ['62944',
#   '69531',
#   '68330',
#   '62967',
#   '62968',
#   '62982',
#   '62970',
#   '62984',
#   '62971',
#   '66769',
#   '67057',
#   '62986',
#   '62973',
#   '62987',
#   '62964',
#   '67058',
#   '62988',
#   '62975',
#   '62965',
#   '62979',
#   '62966'],
#  'please': ['43213',
#   '69434',
#   '70220',
#   '68670',
#   '43225',
#   '43226',
#   '43217',
#   '67083',
#   '43218',
#   '43219',
#   '43220',
#   '43221',
#   '43222',
#   '43223',
#   '43224'],
#  'thank you': ['57653',
#   '69502',
#   '68796',
#   '57663',
#   '57664',
#   '66598',
#   '57655',
#   '57665',
#   '57666',
#   '57667',
#   '57656',
#   '57657',
#   '57658',
#   '57659'],
#  'hello': ['27171',
#   '70017',
#   '68236',
#   '27180',
#   '67755',
#   '27181',
#   '27182',
#   '27183',
#   '27184',
#   '27172',
#   '27173',
#   '27175',
#   '27177'],
#  'love': ['34118',
#   '34123',
#   '34124',
#   '34125',
#   '34127',
#   '34128',
#   '34129',
#   '34121',
#   '34133',
#   '34134',
#   '34136',
#   '34137']}

# %% [markdown]
# ### **Move new videos to target directory and fill in our dict with indexes**

# %%
with open("our_videos_indexes.json", "r") as f2:

    try:
        data = json.load(f2)
    except json.JSONDecodeError:
        data = {}

    for label in os.listdir('our_videos_CV'):
        for video in os.listdir(os.path.join('our_videos_CV', label)):

            if not os.path.exists(os.path.join(path_to_folder_with_videos, video)):
                shutil.move(os.path.join('our_videos_CV', label, video), os.path.join(path_to_folder_with_videos, video))

            if not data.get(label):
                data[label] = []

            if video not in data[label]:
                data[label].append(video.split(".")[0])

    for label, indexes in data.items():
        
        try:
            videos_indexes_dict[label].extend(indexes)
        except KeyError:
            continue
        
with open("our_videos_indexes.json", "w") as f3:
    new_data = json.dump(data, f3)

# %%
videos_indexes_dict
# Out:
# {'what': ['62944',
#   '69531',
#   '68330',
#   '62967',
#   '62968',
#   '62982',
#   '62970',
#   '62984',
#   '62971',
#   '66769',
#   '67057',
#   '62986',
#   '62973',
#   '62987',
#   '62964',
#   '67058',
#   '62988',
#   '62975',
#   '62965',
#   '62979',
#   '62966',
#   '0006_Michal_what',
#   '0003_Marcin_what',
#   '0004_Stefan_what',
#   'IMG_7109',
#   'IMG_7107',
#   'IMG_7105',
#   'IMG_7102',
#   'IMG_7100',
#   'IMG_7097',
#   '0001_Piotrek',
#   '0002_Piotrek',
#   '0030_Pawel',
#   '315660794_5737330542972529_3137644611967061033_n',
#   '315667298_5538013912980151_8041855435225314858_n',
#   '315676582_8325811004158012_7358575957107178723_n',
#   '315681772_5839689206092977_4388615138539721863_n',
#   '315975200_5119105354855696_7130324827507709116_n',
#   '316177093_5893836614012038_8296374439895096079_n',
#   '316241148_8209053445832037_7699394294060366883_n',
#   '316324152_8218071561599820_4430118803425937420_n',
#   '316364046_5978836185484130_1501040512796179661_n',
#   '316378055_9028406133839871_434044695211354231_n',
#   '316383479_5599256033502082_5209859571358498713_n',
#   '316479359_5300582020047246_3819302706393631278_n',
#   '322648811_8840867659258518_5351382910370225924_n',
#   '323280861_5998151600246857_8796522293013181184_n',
#   '323419158_8457587544312037_3897155433870380465_n',
#   '323450666_8863375050346799_469760782717143524_n',
#   '323453751_8966105180074022_2826815444767503909_n',
#   '323796240_5753068901454205_88050558482957590_n',
#   '322606814_6236404346372577_4235322621766111739_n',
#   '322920344_5551651098291334_6282454071764668657_n',
#   '323009106_6149443995079349_8934138507637936009_n',
#   '323683472_5906771876055796_1019231291903561879_n',
#   '323714225_9346125188746427_2615379906657476219_n',
#   '324337652_6057155851011994_484103606256421310_n',
#   '324408079_8471771102894175_990846606789254112_n',
#   '324859248_5791142187659243_1023929225433600984_n',
#   '324935351_6200301796725763_6125128107224708014_n',
#   '325019297_5504335286361222_6562463292790795922_n',
#   '323697667_6076253762426225_254042038517677181_n'],
#  'please': ['43213',
#   '69434',
#   '70220',
#   '68670',
#   '43225',
#   '43226',
#   '43217',
#   '67083',
#   '43218',
#   '43219',
#   '43220',
#   '43221',
#   '43222',
#   '43223',
#   '43224',
#   '0002_Marcin_please',
#   '0005_Michal_please',
#   '0001_Stefan_please',
#   'IMG_7108',
#   'IMG_7106',
#   'IMG_7104',
#   'IMG_7101',
#   'IMG_7098',
#   'IMG_7095',
#   '0003_Piotrek',
#   '0004_Piotrek',
#   '0005_Piotrek',
#   '0006_Piotrek',
#   '0007_Piotrek',
#   '0008_Piotrek',
#   '0009_Piotrek',
#   '0010_piotrek',
#   '0011_Piotrek',
#   '0012_Piotrek',
#   '315655901_5104375596331206_3543365969692386162_n',
#   '315656836_4099965493460470_760282758767464249_n',
#   '315657363_5315525738575923_2336319248528304951_n',
#   '315666482_8215949598478577_5448997221380429303_n',
#   '315667516_8256149691124234_5139338952143164994_n',
#   '315668010_5606311906101934_8840424701460858051_n',
#   '315672950_5647357585317321_3819935764645780381_n',
#   '315743245_5814587518601691_2580139170401635669_n',
#   '316131412_5392611324183943_6667869549816767717_n',
#   '316229141_5360630590733246_8711345663972446608_n',
#   '316366575_5740996555967317_131122250983185571_n',
#   '315655901_5104375596331206_3543365969692386162_n',
#   '315656836_4099965493460470_760282758767464249_n',
#   '315657363_5315525738575923_2336319248528304951_n',
#   '315662831_5569278169807369_7956799844279816859_n',
#   '315664837_5962106660488518_3698305593167238351_n',
#   '315667516_8256149691124234_5139338952143164994_n',
#   '315668010_5606311906101934_8840424701460858051_n',
#   '315672950_5647357585317321_3819935764645780381_n',
#   '315743245_5814587518601691_2580139170401635669_n',
#   '316121810_8287809754626917_1467558168915609951_n',
#   '316131412_5392611324183943_6667869549816767717_n',
#   '316229141_5360630590733246_8711345663972446608_n',
#   '316366575_5740996555967317_131122250983185571_n',
#   '340527856_6868134376549252_3790525746708770416_n',
#   '340530588_9036268683115221_8631304291211556795_n',
#   '340531892_6787786104568914_6554776735063731172_n',
#   '340535036_6888430721184473_9171627785236476579_n',
#   '340535651_6030334620375359_1733463819274478397_n',
#   '340542460_6665226823507022_6175223757565796406_n',
#   '340658154_5893154924146322_5155817223749003930_n',
#   '340661133_6089958717784085_1953976453493072274_n',
#   '340661879_5899372080180124_8917025803662439835_n',
#   '340662930_5806870166090506_8650123416889882653_n',
#   '340664192_6333512530041444_6819723730700705564_n',
#   '340720711_5904954266280461_7419606512163720152_n',
#   '340853428_5877490599015749_4435555508349370663_n',
#   '340858941_6452614871429929_5075394733223642057_n',
#   '340873086_6930548093638556_4960799560428977032_n',
#   '340873799_6016270928472150_7623991424893126732_n',
#   '340884680_8950109268397260_5596309537474208549_n',
#   '340895279_5880715168693927_577655436178661332_n',
#   '341046056_5801024573339738_7262892213314133588_n',
#   '341071719_6284393378262287_8018097358796732027_n',
#   '341187145_6281177791945093_6346114779475774183_n',
#   '341190527_6319402931431335_8461508275203513181_n',
#   '341194298_6168131519946756_1178847359229263572_n',
#   '341414908_9237862749589586_8240333499189224053_n',
#   'edited_m',
#   '315655901_5104375596331206_3543365969692386162_n',
#   '315656836_4099965493460470_760282758767464249_n',
#   '315657363_5315525738575923_2336319248528304951_n',
#   '315667516_8256149691124234_5139338952143164994_n',
#   '315668010_5606311906101934_8840424701460858051_n',
#   '315672950_5647357585317321_3819935764645780381_n',
#   '315743245_5814587518601691_2580139170401635669_n',
#   '316131412_5392611324183943_6667869549816767717_n',
#   '316229141_5360630590733246_8711345663972446608_n'],
#  'thank you': ['57653',
#   '69502',
#   '68796',
#   '57663',
#   '57664',
#   '66598',
#   '57655',
#   '57665',
#   '57666',
#   '57667',
#   '57656',
#   '57657',
#   '57658',
#   '57659',
#   '327442836_6256528971110242_4669953975687634078_n1',
#   '328335006_6166896323391300_2220627740025585340_n1',
#   '329282582_6257077581019092_418229597378435253_n1',
#   '329294420_6286807091399312_4735473790691011888_n1',
#   '329548316_6044331708994426_6027740692386293253_n1',
#   '329557067_6374387792612408_3188483059427552411_n1',
#   '329652938_6414162238628995_6878210054316508310_n1',
#   '340529369_5918741208222598_1475582723172392431_n',
#   '340530112_6573513362682495_897782802585906137_n',
#   '340532218_6816280651721858_6099768454499713127_n1',
#   '340532824_9112820398789467_4936179866316901979_n',
#   '340534688_6164259490332520_2520121755840977359_n',
#   '340534702_5981791915271994_3579389547132122258_n',
#   '340535043_5925907490852135_734042876852621626_n',
#   '340535653_5625327934239096_3159778333655123681_n',
#   '340536401_9219469291428886_8142533364310614468_n',
#   '340539025_6380735598614651_8397068697007540_n',
#   '340540960_6076542842441180_1566843790417513589_n',
#   '340655072_6081931445231206_3886067138346997437_n',
#   '340658135_6212123945511459_7532307365385356717_n',
#   '340658158_6435302323147854_4949255526854419965_n',
#   '340662361_6176732245697734_7729928100461941895_n',
#   '340662375_9408902365816822_3894164107085229319_n',
#   '340663835_6107601605983544_5859963005736273823_n',
#   '340664669_9974788032546672_2527380088908656674_n',
#   '340664962_9309836559088889_3118559244441530736_n',
#   '340666907_9045950888812052_6840131721823890973_n',
#   '340667297_5829381183839315_6749060754104405769_n',
#   '340668348_6039435496140453_3540696293383143983_n',
#   '340699440_6186623231428867_6561803743048736204_n',
#   '340701980_6356240351133144_3370624087128136604_n',
#   '340704315_5882059778583195_2974288717537891416_n',
#   '340861002_6320935971270936_84076230118793593_n1',
#   '340861320_5921835134600527_7226489013201371187_n',
#   '340861526_6063580857012828_80466608888013478_n1',
#   '340862956_6033277703386152_5859333087694855470_n1',
#   '340863719_5815725365202939_2356467015686065728_n1',
#   '340865588_6211462355576980_3412492520610609125_n1',
#   '340874881_6297685113584785_8312027313169781375_n',
#   '340891851_6087783664620636_4058169191763830573_n1',
#   '341032618_6155883767835985_2945578267973218633_n1',
#   '341032978_6042672285841448_2288205140019419398_n1',
#   '341042855_6022815934433896_6157056153972631768_n',
#   '341044038_9093228717416297_7203676684468472647_n1',
#   '341058293_6331713146880593_8960205292598395909_n',
#   '341067268_6031514443584973_3402776482005743287_n',
#   '341207325_6488918097794237_6291617420373263903_n',
#   '341218038_6533656590002278_8330216173254288946_n',
#   '341347945_5995825120538832_1997517716427377311_n1',
#   '341385564_6004258562955776_7768190375894169302_n',
#   '341432055_9851929831499355_4400624344321955001_n',
#   '341558621_6306868379365088_1847716467978947452_n'],
#  'hello': ['27171',
#   '70017',
#   '68236',
#   '27180',
#   '67755',
#   '27181',
#   '27182',
#   '27183',
#   '27184',
#   '27172',
#   '27173',
#   '27175',
#   '27177',
#   '316593916_5869504323099568_5188290008539283818_n',
#   '316600757_5975326595860077_5812202084396398372_n',
#   '316603556_6252045531474102_68496911081437090_n',
#   '316604675_5888487564566960_1510929581994726296_n',
#   '316613103_5452131071551005_7895041952245026910_n',
#   '316905456_5444796248952625_8054280494169079753_n',
#   '317299683_6366274306750090_6098189900194390988_n',
#   '317303097_5659376534175981_4865995792359444924_n',
#   '317390773_5660239520679683_3919899520370220520_n',
#   '317401412_5769276686487732_4499619589161281199_n',
#   '317421468_8641214345953155_1036226580057999064_n',
#   '316597170_5644893462297704_5114199198249950744_n',
#   '316598321_5580456551990268_5733048303231911812_n',
#   '316599301_5453640311400112_1743415857195457609_n',
#   '316600753_8388305714576753_3533753461869442421_n',
#   '316602501_5835131283175606_7260672321814878160_n',
#   '316602697_6054028784629610_6761389275781498993_n',
#   '316602724_5719882928101771_4835252765302542443_n',
#   '316602730_5770695746321827_6973901687013873330_n',
#   '316603951_5830716060323346_1493605877956294231_n',
#   '316604679_4074798672644081_3146396946702490578_n',
#   '316612070_8334232603317261_8404286800558618829_n',
#   '316624690_5719165514825839_298188178213210153_n',
#   '316633323_5219548848150167_5067907597501246016_n',
#   '316873338_5964571416895046_6844949194389695818_n',
#   '317291969_5198913946880938_9109047139976121205_n',
#   '317302684_5844404648931210_2279192474729520794_n',
#   '317375971_8236052526469148_224989135656153463_n',
#   '317393307_8633806196660267_2476652811705833817_n',
#   '317396186_8357800687595540_4743893869917727623_n',
#   '317403160_8756894367714885_5001106211085392129_n',
#   '323471060_9023484437676620_2761622652186876226_n',
#   '323813743_5688365851251957_5507314426463413357_n',
#   '323828023_6252744131404956_8535040985973990169_n',
#   '324094001_8546778135393514_9083967731325223677_n',
#   '322953916_5609350909118828_1856674125230928568_n',
#   '323067717_5602380716557291_1254183980873629894_n',
#   '323247606_5871915369537367_1377417356143944307_n',
#   '323262833_5565533543557833_4914508034061777211_n',
#   '323561172_5633806700001173_5290733675826392182_n',
#   '323666276_8679664952074494_6103487149711556881_n (1)',
#   '323806425_5759032527509986_4430821625415773253_n',
#   '323727945_5973884582696072_1308655529815370332_n',
#   '323740933_9030081733698832_4386570349517025088_n',
#   '323741777_5815872845133853_5192239663458510534_n',
#   '323893961_6280412428645987_6898433292482928739_n',
#   '324095103_6097608773625222_2737893610474357308_n',
#   '324115442_5757920324297045_5747435849901713187_n',
#   '325024118_9034193869931808_6844341851898488691_n'],
#  'love': ['34118',
#   '34123',
#   '34124',
#   '34125',
#   '34127',
#   '34128',
#   '34129',
#   '34121',
#   '34133',
#   '34134',
#   '34136',
#   '34137',
#   '316581323_5742042269223852_2690521158285268813_n',
#   '316582438_6011044305581058_6429931126758510390_n',
#   '316584523_5755267354509952_1576426240286021064_n',
#   '316595049_8332233906851267_2353779844513719311_n',
#   '316597762_6149252418428092_7623550947793137283_n',
#   '316605945_5289609427827664_8326039063429879608_n',
#   '317252578_9009949229018915_9015381801941564891_n',
#   '317280293_8351990591539945_1391379902196109882_n',
#   '317286323_8674791742538752_5335346519886806392_n',
#   '317292789_8283501085054394_3121103993078430126_n',
#   '317293021_6192272624140828_785137499218837023_n',
#   '317412553_5845975618788219_3619129305930607493_n',
#   '317413117_5617894188330929_2467628522303653011_n',
#   '317419628_5832561680098184_2873941736892351839_n',
#   '316586492_5571617026268136_115148371584645224_n',
#   '316591605_5340149052780520_6005402944349282848_n',
#   '316601589_5313491915423735_4837069154808254607_n',
#   '316611779_8285851651484925_5296098144078241189_n',
#   '316612550_6284842641530363_6511903022273171662_n',
#   '316614652_5763236393733957_7633444034609908983_n',
#   '316620893_5384254868352043_6697530978043356353_n',
#   '317254076_5910979238933128_2662474548071225351_n',
#   '317290891_8382707321770616_7596948413298229397_n',
#   '317398345_8387453867994517_5716247659500591400_n',
#   '317403252_6099652290066819_8587645014174354645_n',
#   '317407352_8285070351534552_8042933039908723108_n',
#   '317412461_5453876061400915_7571582504830399432_n',
#   '317419043_6123555051012503_3700169924327968811_n',
#   '322644622_5950210405029743_5587840321871480448_n',
#   '322650722_5856287137792079_3155806238135541995_n',
#   '323435561_5919959704733103_2260398543487940589_n',
#   '323452790_5772463219501674_8793550728624889640_n',
#   '323584676_5824396677647459_6068147122190389814_n',
#   '323904973_6020962587925937_1194949491088158351_n',
#   '324112959_6251787688178234_5223923111029423251_n',
#   '322920090_9417564478269306_5421481744261379206_n',
#   '322923391_8806350882716042_2924067792123814125_n',
#   '322924593_5698417653545572_715846106722313169_n',
#   '322939013_5336596216446331_2896721270074798771_n',
#   '322939033_8466519083420839_6261810109312080843_n',
#   '323259116_5721528741301030_2201039101993053961_n',
#   '323269366_6510814342266945_1038174905649828007_n',
#   '323659001_6247594481942135_5097707896613563282_n',
#   '323746605_6530342773647998_5941468406632394559_n (1)',
#   '324501402_5957831714260358_1957924005950383286_n',
#   '323685716_8856922054348468_927822040383097001_n']}

# %% [markdown]
# ### **Chosing only these which are not present in missing.txt**

# %%
with open('missing.txt', 'r') as miss:
    missing_indexes = miss.readlines()
    missing_indexes = [index.strip() for index in missing_indexes]

# %%
cleared_videos_indexes_dict = {label: list(set(label_indexes).difference(set(missing_indexes))) for label, label_indexes in videos_indexes_dict.items()}

# %%
def delete_unused_videos(used_video_indexes, path_to_folder_with_videos):

    used_videos = []

    for label, videos_indexes in used_video_indexes.items():
        used_videos.extend(list(videos_indexes))

    for video_name in os.listdir(path_to_folder_with_videos):
        if video_name.split('.')[0] not in used_videos:
            os.remove(os.path.join(path_to_folder_with_videos, video_name))

# %%
def begin_and_end(number: int):

    if number == 1:
        return 1, 0
    
    if number % 2 == 0:
        from_beginning, from_ending = number / 2, number / 2
    else:
        from_beginning, from_ending = number // 2 + 1, number // 2

    return int(from_beginning), int(from_ending)

# %%
def get_canny_frame(frame, apply_median_filter=True, filter_power=6):

    if apply_median_filter:
        frame = median_filter(frame, filter_power)
            
    return cv2.Canny(frame, 100, 200)

# %%
def remove_background(mp_selfie_segmentation, frame, background_color):

    with mp_selfie_segmentation.SelfieSegmentation(model_selection=1) as selfie_segmentation:

        image = cv2.cvtColor(cv2.flip(frame, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = selfie_segmentation.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 0.1

        background = np.zeros(image.shape, dtype=np.uint8)
        background[:] = background_color
        
        output_image = cv2.flip(np.where(condition, image, background), 1)

    return output_image

# %%
def extract_keypoints(results):

    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    # face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
    return np.concatenate([pose, lh, rh])

# %% [markdown]
# ### **Getting frames from chosen videos**

# %%
keypoints_or_photos = "chosen_keypoints"

# %%
if os.path.exists(keypoints_or_photos):
    shutil.rmtree(keypoints_or_photos)
    
if not os.path.exists(keypoints_or_photos):
    os.mkdir(keypoints_or_photos)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for label, label_indexes in cleared_videos_indexes_dict.items():

        if not os.path.exists(f'{keypoints_or_photos}/{label}'):
            os.mkdir(f'{keypoints_or_photos}/{label}')

        for video_index in label_indexes:

            path_to_video = f'{path_to_folder_with_videos}/{video_index}.mp4'
            if not os.path.exists(path_to_video):
                print(f'{path_to_video} does not exist!')
                continue
            
            capture = cv2.VideoCapture(path_to_video)
            video_length = int(capture.get(cv2.CAP_PROP_FRAME_COUNT))
            
            step = max(round(video_length / SEQUENCE_LENGTH, 0), 1)

            video_frames = []
            success, frame = capture.read()
            frame_nr = 1
            counter = 1

            while success:
                success, frame = capture.read()

                if success and counter % step == 0: 
                    
                    video_frames.append(frame)
                    frame_nr += 1

                counter += 1

            if len(video_frames) != 25:
                
                if len(video_frames) > 25:
                    excess = len(video_frames) - 25
                    from_beginning, from_ending = begin_and_end(excess)
                    video_frames = video_frames[from_beginning:-from_ending]

                else:
                    shortage = 25 - len(video_frames)
                    black_image = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 3), dtype=np.uint8)
                    from_beginning, from_ending = begin_and_end(shortage)
                    video_frames = [black_image] * from_beginning + video_frames + [black_image] * from_ending

            if len(video_frames) != 25:
                continue
            
            for frame_index, frame in enumerate(video_frames, start=1):
                path_to_frame = f'{keypoints_or_photos}/{label}/{video_index}-{frame_index}.jpg'

                if not os.path.exists(path_to_frame):
                    
                    # frame = remove_background(mp_selfie_segmentation, frame, BG_COLOR)
                    resized_frame = cv2.resize(frame, IMAGE_SIZE)
                    image, results = mediapipe_detection(resized_frame, holistic)
                    # draw_styled_landmarks(image, results)

                    keypoints = extract_keypoints(results)
                    np.save(path_to_frame, keypoints)

                    # grayscale_resized_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2GRAY)
                    # canny_frame = get_canny_frame(grayscale_resized_frame)
                    # cv2.imwrite(path_to_frame, canny_frame)

            capture.release()
# Out:
# sign_language_videos/0006_Michal_what.mp4 does not exist!
# sign_language_videos/62988.mp4 does not exist!
# sign_language_videos/62966.mp4 does not exist!
# sign_language_videos/0004_Stefan_what.mp4 does not exist!
# sign_language_videos/62967.mp4 does not exist!
# sign_language_videos/66769.mp4 does not exist!
# sign_language_videos/62979.mp4 does not exist!
# sign_language_videos/340658154_5893154924146322_5155817223749003930_n.mp4 does not exist!
# sign_language_videos/315662831_5569278169807369_7956799844279816859_n.mp4 does not exist!
# sign_language_videos/340535036_6888430721184473_9171627785236476579_n.mp4 does not exist!
# sign_language_videos/315666482_8215949598478577_5448997221380429303_n.mp4 does not exist!
# sign_language_videos/0005_Michal_please.mp4 does not exist!
# sign_language_videos/66598.mp4 does not exist!
# sign_language_videos/57657.mp4 does not exist!
# sign_language_videos/57655.mp4 does not exist!
# sign_language_videos/69502.mp4 does not exist!
# sign_language_videos/57656.mp4 does not exist!
# sign_language_videos/57667.mp4 does not exist!
# sign_language_videos/57659.mp4 does not exist!
# sign_language_videos/316603951_5830716060323346_1493605877956294231_n.mp4 does not exist!
# sign_language_videos/323741777_5815872845133853_5192239663458510534_n.mp4 does not exist!
# sign_language_videos/316582438_6011044305581058_6429931126758510390_n.mp4 does not exist!

# %% [markdown]
# ### **How many instances of each class**

# %%
for label, indexes in cleared_videos_indexes_dict.items():
    print(f"{label} - {len(indexes)} instances")
# Out:
# what - 53 instances
# please - 65 instances
# thank you - 59 instances
# hello - 53 instances
# love - 53 instances

# %%
cleared_videos_indexes_dict
# Out:
# {'what': ['324408079_8471771102894175_990846606789254112_n',
#   '323697667_6076253762426225_254042038517677181_n',
#   '316383479_5599256033502082_5209859571358498713_n',
#   '0006_Michal_what',
#   'IMG_7107',
#   '316241148_8209053445832037_7699394294060366883_n',
#   'IMG_7105',
#   'IMG_7109',
#   '325019297_5504335286361222_6562463292790795922_n',
#   '315676582_8325811004158012_7358575957107178723_n',
#   '322648811_8840867659258518_5351382910370225924_n',
#   '316177093_5893836614012038_8296374439895096079_n',
#   '324935351_6200301796725763_6125128107224708014_n',
#   '0030_Pawel',
#   '62987',
#   '69531',
#   '0002_Piotrek',
#   '315667298_5538013912980151_8041855435225314858_n',
#   '316364046_5978836185484130_1501040512796179661_n',
#   '0003_Marcin_what',
#   '62988',
#   '315681772_5839689206092977_4388615138539721863_n',
#   '62970',
#   '316479359_5300582020047246_3819302706393631278_n',
#   '323796240_5753068901454205_88050558482957590_n',
#   '323419158_8457587544312037_3897155433870380465_n',
#   '323450666_8863375050346799_469760782717143524_n',
#   '316378055_9028406133839871_434044695211354231_n',
#   '0001_Piotrek',
#   '323683472_5906771876055796_1019231291903561879_n',
#   '316324152_8218071561599820_4430118803425937420_n',
#   'IMG_7100',
#   '62975',
#   '62966',
#   '62965',
#   'IMG_7102',
#   '323280861_5998151600246857_8796522293013181184_n',
#   '323714225_9346125188746427_2615379906657476219_n',
#   '0004_Stefan_what',
#   '315975200_5119105354855696_7130324827507709116_n',
#   '62968',
#   '323453751_8966105180074022_2826815444767503909_n',
#   '322606814_6236404346372577_4235322621766111739_n',
#   '324337652_6057155851011994_484103606256421310_n',
#   '62964',
#   '315660794_5737330542972529_3137644611967061033_n',
#   '62967',
#   'IMG_7097',
#   '322920344_5551651098291334_6282454071764668657_n',
#   '323009106_6149443995079349_8934138507637936009_n',
#   '66769',
#   '324859248_5791142187659243_1023929225433600984_n',
#   '62979'],
#  'please': ['IMG_7098',
#   '0003_Piotrek',
#   '315664837_5962106660488518_3698305593167238351_n',
#   '315655901_5104375596331206_3543365969692386162_n',
#   '0008_Piotrek',
#   '315667516_8256149691124234_5139338952143164994_n',
#   '340535651_6030334620375359_1733463819274478397_n',
#   '316229141_5360630590733246_8711345663972446608_n',
#   '340658154_5893154924146322_5155817223749003930_n',
#   '340873086_6930548093638556_4960799560428977032_n',
#   '341194298_6168131519946756_1178847359229263572_n',
#   '0004_Piotrek',
#   '315662831_5569278169807369_7956799844279816859_n',
#   '0009_Piotrek',
#   '340664192_6333512530041444_6819723730700705564_n',
#   '340895279_5880715168693927_577655436178661332_n',
#   '43226',
#   '341046056_5801024573339738_7262892213314133588_n',
#   '315672950_5647357585317321_3819935764645780381_n',
#   '43219',
#   '0002_Marcin_please',
#   'edited_m',
#   '315657363_5315525738575923_2336319248528304951_n',
#   '341190527_6319402931431335_8461508275203513181_n',
#   '340884680_8950109268397260_5596309537474208549_n',
#   '340542460_6665226823507022_6175223757565796406_n',
#   '0010_piotrek',
#   '340662930_5806870166090506_8650123416889882653_n',
#   '340527856_6868134376549252_3790525746708770416_n',
#   '340531892_6787786104568914_6554776735063731172_n',
#   '0007_Piotrek',
#   '0005_Piotrek',
#   '43222',
#   '43217',
#   '340535036_6888430721184473_9171627785236476579_n',
#   '316366575_5740996555967317_131122250983185571_n',
#   '341187145_6281177791945093_6346114779475774183_n',
#   '340530588_9036268683115221_8631304291211556795_n',
#   '340720711_5904954266280461_7419606512163720152_n',
#   '340661879_5899372080180124_8917025803662439835_n',
#   '340858941_6452614871429929_5075394733223642057_n',
#   '315656836_4099965493460470_760282758767464249_n',
#   '0006_Piotrek',
#   'IMG_7101',
#   '316121810_8287809754626917_1467558168915609951_n',
#   'IMG_7095',
#   '315666482_8215949598478577_5448997221380429303_n',
#   '341414908_9237862749589586_8240333499189224053_n',
#   '315743245_5814587518601691_2580139170401635669_n',
#   '340873799_6016270928472150_7623991424893126732_n',
#   '0005_Michal_please',
#   '43220',
#   '69434',
#   '0001_Stefan_please',
#   '340853428_5877490599015749_4435555508349370663_n',
#   'IMG_7104',
#   '43218',
#   '341071719_6284393378262287_8018097358796732027_n',
#   'IMG_7106',
#   '0011_Piotrek',
#   '316131412_5392611324183943_6667869549816767717_n',
#   '315668010_5606311906101934_8840424701460858051_n',
#   'IMG_7108',
#   '340661133_6089958717784085_1953976453493072274_n',
#   '0012_Piotrek'],
#  'thank you': ['341207325_6488918097794237_6291617420373263903_n',
#   '340658135_6212123945511459_7532307365385356717_n',
#   '340862956_6033277703386152_5859333087694855470_n1',
#   '340535043_5925907490852135_734042876852621626_n',
#   '340666907_9045950888812052_6840131721823890973_n',
#   '327442836_6256528971110242_4669953975687634078_n1',
#   '329548316_6044331708994426_6027740692386293253_n1',
#   '340535653_5625327934239096_3159778333655123681_n',
#   '341432055_9851929831499355_4400624344321955001_n',
#   '66598',
#   '340540960_6076542842441180_1566843790417513589_n',
#   '340662361_6176732245697734_7729928100461941895_n',
#   '340865588_6211462355576980_3412492520610609125_n1',
#   '329282582_6257077581019092_418229597378435253_n1',
#   '341067268_6031514443584973_3402776482005743287_n',
#   '329557067_6374387792612408_3188483059427552411_n1',
#   '57657',
#   '340891851_6087783664620636_4058169191763830573_n1',
#   '341558621_6306868379365088_1847716467978947452_n',
#   '340704315_5882059778583195_2974288717537891416_n',
#   '341032978_6042672285841448_2288205140019419398_n1',
#   '341347945_5995825120538832_1997517716427377311_n1',
#   '340663835_6107601605983544_5859963005736273823_n',
#   '57655',
#   '340664669_9974788032546672_2527380088908656674_n',
#   '340532218_6816280651721858_6099768454499713127_n1',
#   '340861526_6063580857012828_80466608888013478_n1',
#   '340662375_9408902365816822_3894164107085229319_n',
#   '340532824_9112820398789467_4936179866316901979_n',
#   '340667297_5829381183839315_6749060754104405769_n',
#   '340863719_5815725365202939_2356467015686065728_n1',
#   '340664962_9309836559088889_3118559244441530736_n',
#   '341044038_9093228717416297_7203676684468472647_n1',
#   '340701980_6356240351133144_3370624087128136604_n',
#   '340874881_6297685113584785_8312027313169781375_n',
#   '340668348_6039435496140453_3540696293383143983_n',
#   '340658158_6435302323147854_4949255526854419965_n',
#   '340699440_6186623231428867_6561803743048736204_n',
#   '340534702_5981791915271994_3579389547132122258_n',
#   '341058293_6331713146880593_8960205292598395909_n',
#   '340534688_6164259490332520_2520121755840977359_n',
#   '69502',
#   '340529369_5918741208222598_1475582723172392431_n',
#   '341032618_6155883767835985_2945578267973218633_n1',
#   '57656',
#   '341218038_6533656590002278_8330216173254288946_n',
#   '340530112_6573513362682495_897782802585906137_n',
#   '340539025_6380735598614651_8397068697007540_n',
#   '340861320_5921835134600527_7226489013201371187_n',
#   '340861002_6320935971270936_84076230118793593_n1',
#   '341042855_6022815934433896_6157056153972631768_n',
#   '328335006_6166896323391300_2220627740025585340_n1',
#   '341385564_6004258562955776_7768190375894169302_n',
#   '340655072_6081931445231206_3886067138346997437_n',
#   '329652938_6414162238628995_6878210054316508310_n1',
#   '57667',
#   '57659',
#   '329294420_6286807091399312_4735473790691011888_n1',
#   '340536401_9219469291428886_8142533364310614468_n'],
#  'hello': ['27173',
#   '325024118_9034193869931808_6844341851898488691_n',
#   '317375971_8236052526469148_224989135656153463_n',
#   '316603951_5830716060323346_1493605877956294231_n',
#   '316604679_4074798672644081_3146396946702490578_n',
#   '317302684_5844404648931210_2279192474729520794_n',
#   '317403160_8756894367714885_5001106211085392129_n',
#   '323067717_5602380716557291_1254183980873629894_n',
#   '27184',
#   '317396186_8357800687595540_4743893869917727623_n',
#   '323471060_9023484437676620_2761622652186876226_n',
#   '316613103_5452131071551005_7895041952245026910_n',
#   '317291969_5198913946880938_9109047139976121205_n',
#   '317401412_5769276686487732_4499619589161281199_n',
#   '324094001_8546778135393514_9083967731325223677_n',
#   '316593916_5869504323099568_5188290008539283818_n',
#   '316905456_5444796248952625_8054280494169079753_n',
#   '323561172_5633806700001173_5290733675826392182_n',
#   '316600757_5975326595860077_5812202084396398372_n',
#   '316602697_6054028784629610_6761389275781498993_n',
#   '316602730_5770695746321827_6973901687013873330_n',
#   '316602724_5719882928101771_4835252765302542443_n',
#   '316603556_6252045531474102_68496911081437090_n',
#   '316604675_5888487564566960_1510929581994726296_n',
#   '322953916_5609350909118828_1856674125230928568_n',
#   '317390773_5660239520679683_3919899520370220520_n',
#   '316600753_8388305714576753_3533753461869442421_n',
#   '323893961_6280412428645987_6898433292482928739_n',
#   '316599301_5453640311400112_1743415857195457609_n',
#   '323813743_5688365851251957_5507314426463413357_n',
#   '323262833_5565533543557833_4914508034061777211_n',
#   '323740933_9030081733698832_4386570349517025088_n',
#   '317303097_5659376534175981_4865995792359444924_n',
#   '323741777_5815872845133853_5192239663458510534_n',
#   '316598321_5580456551990268_5733048303231911812_n',
#   '323806425_5759032527509986_4430821625415773253_n',
#   '316633323_5219548848150167_5067907597501246016_n',
#   '317421468_8641214345953155_1036226580057999064_n',
#   '316873338_5964571416895046_6844949194389695818_n',
#   '323727945_5973884582696072_1308655529815370332_n',
#   '316602501_5835131283175606_7260672321814878160_n',
#   '324115442_5757920324297045_5747435849901713187_n',
#   '324095103_6097608773625222_2737893610474357308_n',
#   '317299683_6366274306750090_6098189900194390988_n',
#   '27177',
#   '27172',
#   '323666276_8679664952074494_6103487149711556881_n (1)',
#   '323828023_6252744131404956_8535040985973990169_n',
#   '317393307_8633806196660267_2476652811705833817_n',
#   '316597170_5644893462297704_5114199198249950744_n',
#   '316624690_5719165514825839_298188178213210153_n',
#   '316612070_8334232603317261_8404286800558618829_n',
#   '323247606_5871915369537367_1377417356143944307_n'],
#  'love': ['316584523_5755267354509952_1576426240286021064_n',
#   '322923391_8806350882716042_2924067792123814125_n',
#   '323259116_5721528741301030_2201039101993053961_n',
#   '322920090_9417564478269306_5421481744261379206_n',
#   '316582438_6011044305581058_6429931126758510390_n',
#   '317252578_9009949229018915_9015381801941564891_n',
#   '317292789_8283501085054394_3121103993078430126_n',
#   '323904973_6020962587925937_1194949491088158351_n',
#   '317286323_8674791742538752_5335346519886806392_n',
#   '322650722_5856287137792079_3155806238135541995_n',
#   '322939033_8466519083420839_6261810109312080843_n',
#   '322644622_5950210405029743_5587840321871480448_n',
#   '317412461_5453876061400915_7571582504830399432_n',
#   '34129',
#   '317254076_5910979238933128_2662474548071225351_n',
#   '316611779_8285851651484925_5296098144078241189_n',
#   '34127',
#   '317412553_5845975618788219_3619129305930607493_n',
#   '316586492_5571617026268136_115148371584645224_n',
#   '323659001_6247594481942135_5097707896613563282_n',
#   '34121',
#   '316591605_5340149052780520_6005402944349282848_n',
#   '316601589_5313491915423735_4837069154808254607_n',
#   '317280293_8351990591539945_1391379902196109882_n',
#   '317419043_6123555051012503_3700169924327968811_n',
#   '324112959_6251787688178234_5223923111029423251_n',
#   '322939013_5336596216446331_2896721270074798771_n',
#   '323685716_8856922054348468_927822040383097001_n',
#   '316612550_6284842641530363_6511903022273171662_n',
#   '34137',
#   '317419628_5832561680098184_2873941736892351839_n',
#   '317398345_8387453867994517_5716247659500591400_n',
#   '317290891_8382707321770616_7596948413298229397_n',
#   '323746605_6530342773647998_5941468406632394559_n (1)',
#   '316605945_5289609427827664_8326039063429879608_n',
#   '316595049_8332233906851267_2353779844513719311_n',
#   '317293021_6192272624140828_785137499218837023_n',
#   '316597762_6149252418428092_7623550947793137283_n',
#   '316581323_5742042269223852_2690521158285268813_n',
#   '317403252_6099652290066819_8587645014174354645_n',
#   '323435561_5919959704733103_2260398543487940589_n',
#   '34124',
#   '34123',
#   '322924593_5698417653545572_715846106722313169_n',
#   '317413117_5617894188330929_2467628522303653011_n',
#   '34128',
#   '316614652_5763236393733957_7633444034609908983_n',
#   '323269366_6510814342266945_1038174905649828007_n',
#   '316620893_5384254868352043_6697530978043356353_n',
#   '323584676_5824396677647459_6068147122190389814_n',
#   '324501402_5957831714260358_1957924005950383286_n',
#   '317407352_8285070351534552_8042933039908723108_n',
#   '323452790_5772463219501674_8793550728624889640_n']}

# %%
if os.path.exists(f'splitted'):
    shutil.rmtree('splitted')

# %%
if not os.path.exists(f'splitted'):
    os.mkdir(f'splitted')

for dataset in ['train', 'val', 'test']:
    if not os.path.exists(f'splitted/{dataset}'):
        os.mkdir(f'splitted/{dataset}')

# %% [markdown]
# ### **Create train, test, validation directories of photos divided also by class**

# %%
for label, samples in cleared_videos_indexes_dict.items():

    train_set, test_set = train_test_split(list(samples), train_size=0.85)
    train_set, validation_set = train_test_split(train_set, test_size=0.15)

    for dataset_name in ['train', 'test', 'val']:
        if not os.path.exists(f'splitted/{dataset_name}/{label}'):
            os.mkdir(f'splitted/{dataset_name}/{label}')

    for image in os.listdir(f'{keypoints_or_photos}/{label}'):
        image_index = image.split('-')[0]

        for dataset, dataset_name in zip([train_set, validation_set, test_set], ['train', 'val', 'test']):
            if image_index in dataset:
               shutil.copyfile(os.path.join(keypoints_or_photos, label, image), os.path.join('splitted', dataset_name, label, image))

# %%
def data_augmentation_from_keras():
    """
        It creates several layers of preprocessing data.
        return: data_augmentation
    """

    data_augmentation = tf.keras.Sequential([
        RandomFlip("horizontal"),
        RandomRotation(0.2),
        RandomZoom(0.1),
        RandomTranslation(0.1, 0.1)
    ])

    return data_augmentation

# %%
def augmented_sample(train_dataset):
    """
        Function which takes one photo from train dataset randomly,
        applies augmentation on it and returns list of augmented images
        train_dataset: batched train data set
        return: list of images of augmented photo
    """

    augmented_photos = []
    data_augmentation = data_augmentation_from_keras()

    for images, _ in train_dataset.take(1):
        for i in range(9):
            augmented_images = data_augmentation(images)
            augmented_photos += [augmented_images[0]]

    return augmented_photos

# %%
classes_dict = {name: i for i, name in enumerate(os.listdir(keypoints_or_photos))}
classes_dict
# Out:
# {'hello': 0, 'love': 1, 'please': 2, 'thank you': 3, 'what': 4}

# %% [markdown]
# ### **Creating train, test and validation sets with tensors**

# %%
x_train, y_train, x_val, y_val, x_test, y_test = [], [], [], [], [], []
for dataset_name, x_dataset, y_dataset in zip(['train', 'val', 'test'], [x_train, x_val, x_test], [y_train, y_val, y_test]):
    for label in os.listdir(os.path.join('splitted', dataset_name)):
        one_video = []
        for counter, image_path in enumerate(os.listdir(os.path.join('splitted', dataset_name, label)), start=1):

            if keypoints_or_photos == "chosen_keypoints":
                one_video.append(np.load(os.path.join('splitted', dataset_name, label, image_path)))
            else:
                one_video.append(imread(os.path.join('splitted', dataset_name, label, image_path)))
                
            if counter % 25 == 0:
                x_dataset.append(np.asarray(one_video).reshape(25, -1))
                y_dataset.append(classes_dict[label])
                one_video.clear()
                
x_train, x_val, x_test = np.asarray(x_train), np.asarray(x_val), np.asarray(x_test)
y_train, y_val, y_test = np.asarray(y_train, dtype=np.float32), np.asarray(y_val, dtype=np.float32), np.asarray(y_test, dtype=np.float32)

# %%
x_train, y_train = shuffle(x_train, y_train, random_state=42)
x_val, y_val = shuffle(x_val, y_val, random_state=42)
x_test, y_test = shuffle(x_test, y_test, random_state=42)

# %%
def reshape_set(dataset):

    shape = list(dataset.shape) + [1]
    dataset = dataset.reshape(tuple(shape))
    
    return dataset

# %%
y_train, y_val, y_test = to_categorical(y_train), to_categorical(y_val), to_categorical(y_test)

# %%
x_train, x_val, x_test = tf.cast(x_train, tf.float32), tf.cast(x_val, tf.float32), tf.cast(x_test, tf.float32)
y_train, y_val, y_test = tf.cast(y_train, tf.float32), tf.cast(y_val, tf.float32), tf.cast(y_test, tf.float32)

# %%
x_train.shape, x_val.shape, x_test.shape
# Out:
# (TensorShape([170, 25, 258]),
#  TensorShape([32, 25, 258]),
#  TensorShape([33, 25, 258]))

# %% [markdown]
# ### **Build a model**

# %%
def build_convlstm_model(input_shape, units):

    DefaultConvLSTM2D = partial(tf.keras.layers.ConvLSTM2D,
                                kernel_size=(3, 3), 
                                padding="same",
                                activation="relu", 
                                kernel_initializer="he_normal", 
                                data_format='channels_last', 
                                recurrent_dropout=0.23,
                                return_sequences=True)
    
    DefaultConv2D = partial(tf.keras.layers.Conv2D,
                                kernel_size=(3, 3),
                                padding="same",
                                strides=(2, 2),
                                kernel_initializer="he_normal", 
                                data_format='channels_last')
    

    model = tf.keras.Sequential([
            tf.keras.layers.Rescaling(1. / 255),

            DefaultConvLSTM2D(filters=8, input_shape=input_shape),
            MaxPooling3D((1, 2, 2), padding='same', data_format='channels_last'),
            TimeDistributed(Dropout(0.3)),

            DefaultConvLSTM2D(filters=16),
            MaxPooling3D((1, 2, 2), padding='same', data_format='channels_last'),
            TimeDistributed(Dropout(0.3)),

            # DefaultConvLSTM2D(filters=12),
            # MaxPooling3D((1, 2, 2), padding='same', data_format='channels_last'),
            # TimeDistributed(Dropout(0.2)),
            
            # TimeDistributed(DefaultConvLSTM2D(filters=64)),
            # TimeDistributed(MaxPooling2D((2, 2), padding='same', data_format='channels_last')),
            #TimeDistributed(BatchNormalization()),

            # TimeDistributed(DefaultConv2D(64)),
            # TimeDistributed(BatchNormalization()),
            # TimeDistributed(Activation('elu')),

            # TimeDistributed(DefaultConv2D(64)),
            # TimeDistributed(BatchNormalization()),
            # TimeDistributed(Activation('elu')),

            Flatten(),
            Dense(units, activation='softmax')

        ])

    return model

# %%
def build_lcrn_model():

    DefaultConv2D = partial(tf.keras.layers.Conv2D,
                            kernel_size=(3, 3), 
                            padding="same",
                            activation="relu", 
                            data_format='channels_last')
    
    DefaultConv3D = partial(tf.keras.layers.Conv3D,
                                kernel_size=(3, 3, 3), 
                                padding="same",
                                activation="relu", 
                                data_format='channels_last')

    DefaultMaxPool2D = partial(MaxPooling2D((2, 2), padding='same', data_format='channels_last'))
    # DefaultMaxPool3D = partial(MaxPooling3D((1, 2, 2), padding='same', data_format='channels_last'))

    model = tf.keras.Sequential([
            Rescaling(1. / 255),

            TimeDistributed(DefaultConv2D(filters=8, input_shape=(25, 160, 160, 3))),
            TimeDistributed(MaxPooling2D((2, 2), padding='same', data_format='channels_last')),
            # MaxPooling3D((1, 2, 2), padding='same', data_format='channels_last'),

            # DefaultConv3D(filters=32),
            # DefaultConv3D(filters=32),
            # MaxPooling3D((1, 2, 2), padding='same', data_format='channels_last'),
            # TimeDistributed(Dropout(0.25)),

            TimeDistributed(DefaultConv2D(filters=16)),
            TimeDistributed(DefaultConv2D(filters=16)),
            TimeDistributed(MaxPooling2D((2, 2), padding='same', data_format='channels_last')),
            TimeDistributed(Dropout(0.2)),

            TimeDistributed(DefaultConv2D(filters=32)),
            TimeDistributed(DefaultConv2D(filters=32)),
            TimeDistributed(MaxPooling2D((2, 2), padding='same', data_format='channels_last')),
            TimeDistributed(Dropout(0.2)),

            TimeDistributed(DefaultConv2D(filters=64)),
            TimeDistributed(DefaultConv2D(filters=64)),
            TimeDistributed(MaxPooling2D((2, 2), padding='same', data_format='channels_last')),
            # tf.keras.layers.TimeDistributed(Dropout(0.25)),

            TimeDistributed(Flatten()),
            LSTM(32, name='lstm_1'),
            # Dropout(0.4),
            # tf.keras.layers.LSTM(32),

            Dense(units=1, activation="sigmoid")

        ])

    return model

# %%
def lstm_model(input_shape, units):

    model = tf.keras.Sequential([
            LSTM(16, return_sequences=True, activation='relu', input_shape=input_shape, recurrent_dropout=0.2),
            LSTM(32, return_sequences=True, activation='relu', recurrent_dropout=0.2),
            LSTM(16, return_sequences=False, activation='relu', recurrent_dropout=0.2),
            Dense(24, activation='elu'),
            Dropout(0.25),
            Dense(12, activation='elu'),
            Dropout(0.25),
            Dense(units=units, activation="softmax")
        ])

    return model

# %% [markdown]
# ### **Set hyperparams and needed callbacks**

# %%
lstm_model = lstm_model(input_shape=(SEQUENCE_LENGTH, x_train.shape[-1]), units=5)

lstm_model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.000045), #choosing optimizer
                    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), #loss function
                    metrics=['categorical_accuracy']) 

# path_to_convlstm_model = os.path.join('models', 'lstm_more_data.ckpt')
path_to_convlstm_history = os.path.join('models', 'lstm_5_classes.csv')

n_epochs = 500
callbacks = [EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True),
             CSVLogger(path_to_convlstm_history, append=True),
             ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=25)]

# %% [markdown]
# ### **Train model**

# %%
conv3_model_history = lstm_model.fit(  x=x_train,
                                        y=y_train,
                                        validation_data=(x_val, y_val),
                                        epochs=n_epochs,
                                        batch_size=12,
                                        workers=-1,
                                        use_multiprocessing=True,
                                        callbacks = callbacks
                                        )
# Out:
# Epoch 1/500
# 15/15 [==============================] - 4s 59ms/step - loss: 1.6138 - categorical_accuracy: 0.2412 - val_loss: 1.6122 - val_categorical_accuracy: 0.3438 - lr: 4.5000e-05
# Epoch 2/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.6128 - categorical_accuracy: 0.2118 - val_loss: 1.6106 - val_categorical_accuracy: 0.3438 - lr: 4.5000e-05
# Epoch 3/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.6192 - categorical_accuracy: 0.2059 - val_loss: 1.6099 - val_categorical_accuracy: 0.3750 - lr: 4.5000e-05
# Epoch 4/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.6141 - categorical_accuracy: 0.2118 - val_loss: 1.6090 - val_categorical_accuracy: 0.3750 - lr: 4.5000e-05
# Epoch 5/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.6051 - categorical_accuracy: 0.1941 - val_loss: 1.6079 - val_categorical_accuracy: 0.3438 - lr: 4.5000e-05
# Epoch 6/500
# 15/15 [==============================] - 0s 32ms/step - loss: 1.6155 - categorical_accuracy: 0.1824 - val_loss: 1.6052 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 7/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.6102 - categorical_accuracy: 0.2176 - val_loss: 1.6019 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 8/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.6089 - categorical_accuracy: 0.2059 - val_loss: 1.5989 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 9/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.6003 - categorical_accuracy: 0.2412 - val_loss: 1.5963 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 10/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5874 - categorical_accuracy: 0.2412 - val_loss: 1.5935 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 11/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.6052 - categorical_accuracy: 0.2118 - val_loss: 1.5893 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 12/500
# 15/15 [==============================] - 0s 27ms/step - loss: 1.6044 - categorical_accuracy: 0.2647 - val_loss: 1.5859 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 13/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5734 - categorical_accuracy: 0.3294 - val_loss: 1.5756 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 14/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5898 - categorical_accuracy: 0.2294 - val_loss: 1.5676 - val_categorical_accuracy: 0.2812 - lr: 4.5000e-05
# Epoch 15/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.6079 - categorical_accuracy: 0.2294 - val_loss: 1.5674 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 16/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5678 - categorical_accuracy: 0.2882 - val_loss: 1.5536 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 17/500
# 15/15 [==============================] - 0s 32ms/step - loss: 1.5709 - categorical_accuracy: 0.2471 - val_loss: 1.5432 - val_categorical_accuracy: 0.3125 - lr: 4.5000e-05
# Epoch 18/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5599 - categorical_accuracy: 0.3059 - val_loss: 1.5261 - val_categorical_accuracy: 0.2812 - lr: 4.5000e-05
# Epoch 19/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5548 - categorical_accuracy: 0.3118 - val_loss: 1.5050 - val_categorical_accuracy: 0.2812 - lr: 4.5000e-05
# Epoch 20/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5579 - categorical_accuracy: 0.2882 - val_loss: 1.4978 - val_categorical_accuracy: 0.3750 - lr: 4.5000e-05
# Epoch 21/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5430 - categorical_accuracy: 0.2412 - val_loss: 1.4764 - val_categorical_accuracy: 0.3438 - lr: 4.5000e-05
# Epoch 22/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5258 - categorical_accuracy: 0.2765 - val_loss: 1.4400 - val_categorical_accuracy: 0.4375 - lr: 4.5000e-05
# Epoch 23/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.4861 - categorical_accuracy: 0.3235 - val_loss: 1.4066 - val_categorical_accuracy: 0.4375 - lr: 4.5000e-05
# Epoch 24/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.4863 - categorical_accuracy: 0.3294 - val_loss: 1.3511 - val_categorical_accuracy: 0.4688 - lr: 4.5000e-05
# Epoch 25/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.4955 - categorical_accuracy: 0.3353 - val_loss: 1.3581 - val_categorical_accuracy: 0.5000 - lr: 4.5000e-05
# Epoch 26/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.5125 - categorical_accuracy: 0.3118 - val_loss: 1.3353 - val_categorical_accuracy: 0.4688 - lr: 4.5000e-05
# Epoch 27/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.4652 - categorical_accuracy: 0.3529 - val_loss: 1.3012 - val_categorical_accuracy: 0.5000 - lr: 4.5000e-05
# Epoch 28/500
# 15/15 [==============================] - 0s 32ms/step - loss: 1.4738 - categorical_accuracy: 0.3000 - val_loss: 1.2857 - val_categorical_accuracy: 0.5312 - lr: 4.5000e-05
# Epoch 29/500
# 15/15 [==============================] - 0s 34ms/step - loss: 1.3974 - categorical_accuracy: 0.3412 - val_loss: 1.3342 - val_categorical_accuracy: 0.4062 - lr: 4.5000e-05
# Epoch 30/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.4529 - categorical_accuracy: 0.3824 - val_loss: 1.2868 - val_categorical_accuracy: 0.5000 - lr: 4.5000e-05
# Epoch 31/500
# 15/15 [==============================] - 0s 31ms/step - loss: 1.4297 - categorical_accuracy: 0.3588 - val_loss: 1.2686 - val_categorical_accuracy: 0.5000 - lr: 4.5000e-05
# Epoch 32/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.4215 - categorical_accuracy: 0.3353 - val_loss: 1.2508 - val_categorical_accuracy: 0.5312 - lr: 4.5000e-05
# Epoch 33/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.4542 - categorical_accuracy: 0.3412 - val_loss: 1.2225 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 34/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3904 - categorical_accuracy: 0.3647 - val_loss: 1.2104 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 35/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.3891 - categorical_accuracy: 0.3412 - val_loss: 1.1854 - val_categorical_accuracy: 0.5312 - lr: 4.5000e-05
# Epoch 36/500
# 15/15 [==============================] - 1s 35ms/step - loss: 1.3622 - categorical_accuracy: 0.3706 - val_loss: 1.1635 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 37/500
# 15/15 [==============================] - 0s 27ms/step - loss: 1.3560 - categorical_accuracy: 0.4059 - val_loss: 1.1546 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 38/500
# 15/15 [==============================] - 1s 33ms/step - loss: 1.3668 - categorical_accuracy: 0.4412 - val_loss: 1.1434 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 39/500
# 15/15 [==============================] - 0s 32ms/step - loss: 1.3497 - categorical_accuracy: 0.4412 - val_loss: 1.2242 - val_categorical_accuracy: 0.4062 - lr: 4.5000e-05
# Epoch 40/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3595 - categorical_accuracy: 0.3882 - val_loss: 1.1095 - val_categorical_accuracy: 0.5312 - lr: 4.5000e-05
# Epoch 41/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3364 - categorical_accuracy: 0.4471 - val_loss: 1.1032 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 42/500
# 15/15 [==============================] - 0s 31ms/step - loss: 1.3230 - categorical_accuracy: 0.4412 - val_loss: 1.2407 - val_categorical_accuracy: 0.4375 - lr: 4.5000e-05
# Epoch 43/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.3496 - categorical_accuracy: 0.3882 - val_loss: 1.1980 - val_categorical_accuracy: 0.4688 - lr: 4.5000e-05
# Epoch 44/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.3416 - categorical_accuracy: 0.4118 - val_loss: 1.1241 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 45/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3099 - categorical_accuracy: 0.4471 - val_loss: 1.0724 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 46/500
# 15/15 [==============================] - 0s 32ms/step - loss: 1.3320 - categorical_accuracy: 0.4176 - val_loss: 1.0599 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 47/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3071 - categorical_accuracy: 0.4176 - val_loss: 1.0717 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 48/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.2575 - categorical_accuracy: 0.4294 - val_loss: 1.0482 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 49/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.2698 - categorical_accuracy: 0.4412 - val_loss: 1.0197 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 50/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.2517 - categorical_accuracy: 0.4294 - val_loss: 1.0168 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 51/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.3425 - categorical_accuracy: 0.4059 - val_loss: 1.0067 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 52/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.1662 - categorical_accuracy: 0.5118 - val_loss: 1.0195 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 53/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1893 - categorical_accuracy: 0.4941 - val_loss: 0.9820 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 54/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1494 - categorical_accuracy: 0.5176 - val_loss: 1.0014 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 55/500
# 15/15 [==============================] - 0s 27ms/step - loss: 1.0970 - categorical_accuracy: 0.4941 - val_loss: 0.9479 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 56/500
# 15/15 [==============================] - 0s 32ms/step - loss: 1.1370 - categorical_accuracy: 0.5235 - val_loss: 1.0338 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 57/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.1652 - categorical_accuracy: 0.4588 - val_loss: 0.9239 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 58/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1079 - categorical_accuracy: 0.5235 - val_loss: 0.9242 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 59/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1714 - categorical_accuracy: 0.4882 - val_loss: 0.9867 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 60/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.1430 - categorical_accuracy: 0.4765 - val_loss: 0.9490 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 61/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0587 - categorical_accuracy: 0.5118 - val_loss: 0.9024 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 62/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0634 - categorical_accuracy: 0.5353 - val_loss: 0.8929 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 63/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0659 - categorical_accuracy: 0.5353 - val_loss: 0.8754 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 64/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0878 - categorical_accuracy: 0.5647 - val_loss: 0.8887 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 65/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1955 - categorical_accuracy: 0.4706 - val_loss: 0.8495 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 66/500
# 15/15 [==============================] - 0s 31ms/step - loss: 1.0961 - categorical_accuracy: 0.5471 - val_loss: 0.8421 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 67/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0767 - categorical_accuracy: 0.5059 - val_loss: 0.8780 - val_categorical_accuracy: 0.5625 - lr: 4.5000e-05
# Epoch 68/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0347 - categorical_accuracy: 0.5353 - val_loss: 0.8356 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 69/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.1556 - categorical_accuracy: 0.5000 - val_loss: 0.8547 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 70/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1267 - categorical_accuracy: 0.5353 - val_loss: 0.8998 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 71/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.1115 - categorical_accuracy: 0.5000 - val_loss: 0.8373 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 72/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0743 - categorical_accuracy: 0.4941 - val_loss: 0.8423 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 73/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0650 - categorical_accuracy: 0.5588 - val_loss: 0.8736 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 74/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0374 - categorical_accuracy: 0.5412 - val_loss: 0.8375 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 75/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0350 - categorical_accuracy: 0.5000 - val_loss: 0.8006 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 76/500
# 15/15 [==============================] - 0s 31ms/step - loss: 1.0353 - categorical_accuracy: 0.5588 - val_loss: 0.8025 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 77/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0224 - categorical_accuracy: 0.5471 - val_loss: 0.7900 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 78/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0507 - categorical_accuracy: 0.5235 - val_loss: 0.8147 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 79/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.9911 - categorical_accuracy: 0.5471 - val_loss: 0.7907 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 80/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0424 - categorical_accuracy: 0.5235 - val_loss: 0.7856 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 81/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0317 - categorical_accuracy: 0.5176 - val_loss: 0.7775 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 82/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9906 - categorical_accuracy: 0.5529 - val_loss: 0.7542 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 83/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9788 - categorical_accuracy: 0.5706 - val_loss: 0.7696 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 84/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0048 - categorical_accuracy: 0.5588 - val_loss: 0.7591 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 85/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.9925 - categorical_accuracy: 0.5059 - val_loss: 0.8192 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 86/500
# 15/15 [==============================] - 0s 30ms/step - loss: 1.0223 - categorical_accuracy: 0.5353 - val_loss: 0.7525 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 87/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9326 - categorical_accuracy: 0.5824 - val_loss: 0.7269 - val_categorical_accuracy: 0.5938 - lr: 4.5000e-05
# Epoch 88/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0029 - categorical_accuracy: 0.5529 - val_loss: 0.7618 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 89/500
# 15/15 [==============================] - 0s 28ms/step - loss: 1.0365 - categorical_accuracy: 0.5588 - val_loss: 0.7433 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 90/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0042 - categorical_accuracy: 0.5412 - val_loss: 0.7223 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 91/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0374 - categorical_accuracy: 0.5000 - val_loss: 0.7344 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 92/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9589 - categorical_accuracy: 0.5529 - val_loss: 0.7890 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 93/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9867 - categorical_accuracy: 0.5529 - val_loss: 0.7277 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 94/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.9269 - categorical_accuracy: 0.6059 - val_loss: 0.7235 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 95/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9936 - categorical_accuracy: 0.5882 - val_loss: 0.7772 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 96/500
# 15/15 [==============================] - 0s 29ms/step - loss: 1.0025 - categorical_accuracy: 0.5353 - val_loss: 0.7571 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 97/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9651 - categorical_accuracy: 0.5471 - val_loss: 0.7059 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 98/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9747 - categorical_accuracy: 0.5471 - val_loss: 0.7003 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 99/500
# 15/15 [==============================] - 0s 27ms/step - loss: 1.0060 - categorical_accuracy: 0.5529 - val_loss: 0.7179 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 100/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9229 - categorical_accuracy: 0.5706 - val_loss: 0.7078 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 101/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9371 - categorical_accuracy: 0.5824 - val_loss: 0.7073 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 102/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.8989 - categorical_accuracy: 0.5765 - val_loss: 0.7285 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 103/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9561 - categorical_accuracy: 0.5882 - val_loss: 0.7066 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 104/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9920 - categorical_accuracy: 0.5765 - val_loss: 0.7049 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 105/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.9637 - categorical_accuracy: 0.6235 - val_loss: 0.6961 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 106/500
# 15/15 [==============================] - 1s 36ms/step - loss: 0.9050 - categorical_accuracy: 0.6118 - val_loss: 0.6945 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 107/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8952 - categorical_accuracy: 0.5824 - val_loss: 0.6888 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 108/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8804 - categorical_accuracy: 0.5882 - val_loss: 0.7027 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 109/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8964 - categorical_accuracy: 0.5882 - val_loss: 0.6811 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 110/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9664 - categorical_accuracy: 0.5235 - val_loss: 0.7031 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 111/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.9402 - categorical_accuracy: 0.5588 - val_loss: 0.6983 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 112/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.9343 - categorical_accuracy: 0.5765 - val_loss: 0.7341 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 113/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9183 - categorical_accuracy: 0.5706 - val_loss: 0.6714 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 114/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.9098 - categorical_accuracy: 0.5529 - val_loss: 0.6668 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 115/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8742 - categorical_accuracy: 0.6235 - val_loss: 0.6583 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 116/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8746 - categorical_accuracy: 0.6588 - val_loss: 0.6519 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 117/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9049 - categorical_accuracy: 0.5941 - val_loss: 0.6956 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 118/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9182 - categorical_accuracy: 0.6000 - val_loss: 0.6732 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 119/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.9019 - categorical_accuracy: 0.6059 - val_loss: 0.6606 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 120/500
# 15/15 [==============================] - 1s 32ms/step - loss: 0.8882 - categorical_accuracy: 0.6529 - val_loss: 0.6982 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 121/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.9250 - categorical_accuracy: 0.5765 - val_loss: 0.6684 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 122/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8531 - categorical_accuracy: 0.6118 - val_loss: 0.6449 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 123/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8229 - categorical_accuracy: 0.6353 - val_loss: 0.6360 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 124/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.8534 - categorical_accuracy: 0.6294 - val_loss: 0.6532 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 125/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.9728 - categorical_accuracy: 0.5588 - val_loss: 0.6384 - val_categorical_accuracy: 0.6250 - lr: 4.5000e-05
# Epoch 126/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.9782 - categorical_accuracy: 0.5706 - val_loss: 0.7196 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 127/500
# 15/15 [==============================] - 1s 34ms/step - loss: 0.9254 - categorical_accuracy: 0.5588 - val_loss: 0.6748 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 128/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8736 - categorical_accuracy: 0.6235 - val_loss: 0.6467 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 129/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8818 - categorical_accuracy: 0.5882 - val_loss: 0.6422 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 130/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9375 - categorical_accuracy: 0.5706 - val_loss: 0.6704 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 131/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.8605 - categorical_accuracy: 0.6235 - val_loss: 0.6262 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 132/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9308 - categorical_accuracy: 0.6000 - val_loss: 0.6272 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 133/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8649 - categorical_accuracy: 0.6412 - val_loss: 0.6205 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 134/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8619 - categorical_accuracy: 0.6176 - val_loss: 0.6135 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 135/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.8223 - categorical_accuracy: 0.6471 - val_loss: 0.6105 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 136/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.8216 - categorical_accuracy: 0.6647 - val_loss: 0.6632 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 137/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8920 - categorical_accuracy: 0.5824 - val_loss: 0.6022 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 138/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.9221 - categorical_accuracy: 0.5882 - val_loss: 0.6047 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 139/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8367 - categorical_accuracy: 0.6647 - val_loss: 0.6077 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 140/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8430 - categorical_accuracy: 0.6235 - val_loss: 0.6053 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 141/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7998 - categorical_accuracy: 0.6529 - val_loss: 0.6046 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 142/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8909 - categorical_accuracy: 0.6235 - val_loss: 0.5993 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 143/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.8523 - categorical_accuracy: 0.6059 - val_loss: 0.6030 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 144/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8600 - categorical_accuracy: 0.6588 - val_loss: 0.6019 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 145/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7810 - categorical_accuracy: 0.6412 - val_loss: 0.5889 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 146/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8444 - categorical_accuracy: 0.6353 - val_loss: 0.5837 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 147/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8137 - categorical_accuracy: 0.6235 - val_loss: 0.5806 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 148/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8956 - categorical_accuracy: 0.5765 - val_loss: 0.5912 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 149/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8065 - categorical_accuracy: 0.6471 - val_loss: 0.5881 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 150/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.7950 - categorical_accuracy: 0.6706 - val_loss: 0.5826 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 151/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.8762 - categorical_accuracy: 0.6235 - val_loss: 0.5878 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 152/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8335 - categorical_accuracy: 0.6176 - val_loss: 0.5814 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 153/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8262 - categorical_accuracy: 0.5765 - val_loss: 0.5780 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 154/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7975 - categorical_accuracy: 0.6706 - val_loss: 0.5719 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 155/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8318 - categorical_accuracy: 0.6353 - val_loss: 0.5685 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 156/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8268 - categorical_accuracy: 0.6176 - val_loss: 0.5789 - val_categorical_accuracy: 0.6562 - lr: 4.5000e-05
# Epoch 157/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7953 - categorical_accuracy: 0.6824 - val_loss: 0.5891 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 158/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.8440 - categorical_accuracy: 0.6235 - val_loss: 0.6031 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 159/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.7956 - categorical_accuracy: 0.6471 - val_loss: 0.5824 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 160/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7915 - categorical_accuracy: 0.7176 - val_loss: 0.5695 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 161/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8224 - categorical_accuracy: 0.6118 - val_loss: 0.5744 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 162/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8111 - categorical_accuracy: 0.6294 - val_loss: 0.5940 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 163/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7397 - categorical_accuracy: 0.7294 - val_loss: 0.5618 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 164/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8294 - categorical_accuracy: 0.6118 - val_loss: 0.5515 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 165/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7769 - categorical_accuracy: 0.6529 - val_loss: 0.5454 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 166/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.7819 - categorical_accuracy: 0.6647 - val_loss: 0.5487 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 167/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7261 - categorical_accuracy: 0.6824 - val_loss: 0.5489 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 168/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.8204 - categorical_accuracy: 0.6118 - val_loss: 0.5540 - val_categorical_accuracy: 0.6875 - lr: 4.5000e-05
# Epoch 169/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8396 - categorical_accuracy: 0.6353 - val_loss: 0.5438 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 170/500
# 15/15 [==============================] - 1s 34ms/step - loss: 0.7418 - categorical_accuracy: 0.6941 - val_loss: 0.5779 - val_categorical_accuracy: 0.7188 - lr: 4.5000e-05
# Epoch 171/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.7621 - categorical_accuracy: 0.6765 - val_loss: 0.5662 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 172/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.8364 - categorical_accuracy: 0.6471 - val_loss: 0.5543 - val_categorical_accuracy: 0.7500 - lr: 4.5000e-05
# Epoch 173/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.8004 - categorical_accuracy: 0.6588 - val_loss: 0.5405 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 174/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8035 - categorical_accuracy: 0.6471 - val_loss: 0.5556 - val_categorical_accuracy: 0.7500 - lr: 4.5000e-05
# Epoch 175/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.7638 - categorical_accuracy: 0.6765 - val_loss: 0.5565 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 176/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7487 - categorical_accuracy: 0.7000 - val_loss: 0.5584 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 177/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7601 - categorical_accuracy: 0.6647 - val_loss: 0.5629 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 178/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7259 - categorical_accuracy: 0.6941 - val_loss: 0.5533 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 179/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8441 - categorical_accuracy: 0.6588 - val_loss: 0.5324 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 180/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.7049 - categorical_accuracy: 0.7000 - val_loss: 0.5369 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 181/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.7464 - categorical_accuracy: 0.6647 - val_loss: 0.5252 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 182/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.8373 - categorical_accuracy: 0.6588 - val_loss: 0.5314 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 183/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.8046 - categorical_accuracy: 0.6471 - val_loss: 0.5252 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 184/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7055 - categorical_accuracy: 0.7765 - val_loss: 0.5231 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 185/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6854 - categorical_accuracy: 0.7412 - val_loss: 0.5093 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 186/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.7630 - categorical_accuracy: 0.6294 - val_loss: 0.5422 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 187/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7712 - categorical_accuracy: 0.6588 - val_loss: 0.5074 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 188/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.7204 - categorical_accuracy: 0.7118 - val_loss: 0.5079 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 189/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7459 - categorical_accuracy: 0.6647 - val_loss: 0.5173 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 190/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7931 - categorical_accuracy: 0.6882 - val_loss: 0.5103 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 191/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6995 - categorical_accuracy: 0.7176 - val_loss: 0.5015 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 192/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7802 - categorical_accuracy: 0.7235 - val_loss: 0.5038 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 193/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6933 - categorical_accuracy: 0.6941 - val_loss: 0.4826 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 194/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7761 - categorical_accuracy: 0.7059 - val_loss: 0.5420 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 195/500
# 15/15 [==============================] - 1s 33ms/step - loss: 0.7467 - categorical_accuracy: 0.6824 - val_loss: 0.4806 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 196/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6618 - categorical_accuracy: 0.7353 - val_loss: 0.4698 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 197/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7254 - categorical_accuracy: 0.7412 - val_loss: 0.5073 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 198/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7150 - categorical_accuracy: 0.7353 - val_loss: 0.4801 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 199/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6929 - categorical_accuracy: 0.7353 - val_loss: 0.4634 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 200/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7263 - categorical_accuracy: 0.7588 - val_loss: 0.5111 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 201/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6790 - categorical_accuracy: 0.7647 - val_loss: 0.4886 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 202/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6935 - categorical_accuracy: 0.7235 - val_loss: 0.4790 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 203/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6890 - categorical_accuracy: 0.7118 - val_loss: 0.4818 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 204/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7618 - categorical_accuracy: 0.7118 - val_loss: 0.4998 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 205/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6467 - categorical_accuracy: 0.7529 - val_loss: 0.4739 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 206/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.6202 - categorical_accuracy: 0.7765 - val_loss: 0.4650 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 207/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.7881 - categorical_accuracy: 0.6941 - val_loss: 0.4864 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 208/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6939 - categorical_accuracy: 0.7118 - val_loss: 0.4615 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 209/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6159 - categorical_accuracy: 0.7824 - val_loss: 0.4839 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 210/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6747 - categorical_accuracy: 0.7353 - val_loss: 0.4854 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 211/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6935 - categorical_accuracy: 0.7235 - val_loss: 0.4378 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 212/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6925 - categorical_accuracy: 0.7353 - val_loss: 0.4478 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 213/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6568 - categorical_accuracy: 0.7529 - val_loss: 0.4941 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 214/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6699 - categorical_accuracy: 0.7529 - val_loss: 0.4973 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 215/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6738 - categorical_accuracy: 0.7588 - val_loss: 0.4675 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 216/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.6274 - categorical_accuracy: 0.7824 - val_loss: 0.4755 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 217/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.7408 - categorical_accuracy: 0.7471 - val_loss: 0.4610 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 218/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.7224 - categorical_accuracy: 0.7647 - val_loss: 0.4579 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 219/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6279 - categorical_accuracy: 0.7647 - val_loss: 0.4589 - val_categorical_accuracy: 0.8125 - lr: 4.5000e-05
# Epoch 220/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6282 - categorical_accuracy: 0.7529 - val_loss: 0.5089 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 221/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.6577 - categorical_accuracy: 0.7118 - val_loss: 0.4595 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 222/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6811 - categorical_accuracy: 0.7353 - val_loss: 0.5512 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 223/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6734 - categorical_accuracy: 0.6941 - val_loss: 0.4622 - val_categorical_accuracy: 0.7812 - lr: 4.5000e-05
# Epoch 224/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.6369 - categorical_accuracy: 0.7412 - val_loss: 0.4442 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 225/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6624 - categorical_accuracy: 0.7647 - val_loss: 0.4297 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 226/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.6237 - categorical_accuracy: 0.7765 - val_loss: 0.4438 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 227/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6523 - categorical_accuracy: 0.7471 - val_loss: 0.4210 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 228/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6518 - categorical_accuracy: 0.7235 - val_loss: 0.4561 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 229/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.6788 - categorical_accuracy: 0.7529 - val_loss: 0.4174 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 230/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6772 - categorical_accuracy: 0.7412 - val_loss: 0.4275 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 231/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.6994 - categorical_accuracy: 0.7176 - val_loss: 0.4409 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 232/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5635 - categorical_accuracy: 0.7882 - val_loss: 0.4035 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 233/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6070 - categorical_accuracy: 0.7471 - val_loss: 0.4436 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 234/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6549 - categorical_accuracy: 0.7706 - val_loss: 0.4287 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 235/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6796 - categorical_accuracy: 0.7529 - val_loss: 0.4166 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 236/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.6032 - categorical_accuracy: 0.7765 - val_loss: 0.4161 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 237/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.6022 - categorical_accuracy: 0.8118 - val_loss: 0.4137 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 238/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.5852 - categorical_accuracy: 0.7941 - val_loss: 0.3851 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 239/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5772 - categorical_accuracy: 0.7882 - val_loss: 0.4229 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 240/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.5842 - categorical_accuracy: 0.8118 - val_loss: 0.3883 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 241/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5871 - categorical_accuracy: 0.8118 - val_loss: 0.3880 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 242/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5893 - categorical_accuracy: 0.7882 - val_loss: 0.3896 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 243/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5961 - categorical_accuracy: 0.8059 - val_loss: 0.4150 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 244/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.5771 - categorical_accuracy: 0.7941 - val_loss: 0.3670 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 245/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5818 - categorical_accuracy: 0.8176 - val_loss: 0.3910 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 246/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5856 - categorical_accuracy: 0.8059 - val_loss: 0.3764 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 247/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5366 - categorical_accuracy: 0.8412 - val_loss: 0.3980 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 248/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5608 - categorical_accuracy: 0.8176 - val_loss: 0.3764 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 249/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5399 - categorical_accuracy: 0.8059 - val_loss: 0.3837 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 250/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.5410 - categorical_accuracy: 0.8118 - val_loss: 0.3537 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 251/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6496 - categorical_accuracy: 0.7471 - val_loss: 0.3707 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 252/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.5623 - categorical_accuracy: 0.8176 - val_loss: 0.3980 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 253/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.5050 - categorical_accuracy: 0.8412 - val_loss: 0.3965 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 254/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.5475 - categorical_accuracy: 0.8294 - val_loss: 0.4274 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 255/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.6315 - categorical_accuracy: 0.7588 - val_loss: 0.3623 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 256/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.6052 - categorical_accuracy: 0.7647 - val_loss: 0.3702 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 257/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5383 - categorical_accuracy: 0.8059 - val_loss: 0.3640 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 258/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.5601 - categorical_accuracy: 0.7647 - val_loss: 0.3524 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 259/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.5091 - categorical_accuracy: 0.8588 - val_loss: 0.3816 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 260/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5518 - categorical_accuracy: 0.8176 - val_loss: 0.3643 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# ...
# Epoch 415/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.3211 - categorical_accuracy: 0.8941 - val_loss: 0.2449 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 416/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.2725 - categorical_accuracy: 0.9353 - val_loss: 0.2291 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 417/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.3113 - categorical_accuracy: 0.8882 - val_loss: 0.2207 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 418/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2841 - categorical_accuracy: 0.9000 - val_loss: 0.2147 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 419/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3019 - categorical_accuracy: 0.9118 - val_loss: 0.1935 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 420/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.3017 - categorical_accuracy: 0.8882 - val_loss: 0.2247 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 421/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2720 - categorical_accuracy: 0.9059 - val_loss: 0.2571 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 422/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.2508 - categorical_accuracy: 0.9294 - val_loss: 0.2001 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 423/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2504 - categorical_accuracy: 0.9176 - val_loss: 0.2157 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 424/500
# 15/15 [==============================] - 0s 34ms/step - loss: 0.2240 - categorical_accuracy: 0.9235 - val_loss: 0.2223 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 425/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.3074 - categorical_accuracy: 0.9000 - val_loss: 0.1843 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 426/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3678 - categorical_accuracy: 0.8882 - val_loss: 0.1912 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 427/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.2855 - categorical_accuracy: 0.9059 - val_loss: 0.1989 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 428/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2851 - categorical_accuracy: 0.9000 - val_loss: 0.2674 - val_categorical_accuracy: 0.8438 - lr: 4.5000e-05
# Epoch 429/500
# 15/15 [==============================] - 1s 33ms/step - loss: 0.2911 - categorical_accuracy: 0.9176 - val_loss: 0.2470 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 430/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.2845 - categorical_accuracy: 0.9118 - val_loss: 0.2155 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 431/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3263 - categorical_accuracy: 0.8882 - val_loss: 0.1946 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 432/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3313 - categorical_accuracy: 0.9000 - val_loss: 0.1996 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 433/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2975 - categorical_accuracy: 0.8882 - val_loss: 0.1883 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 434/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2894 - categorical_accuracy: 0.9176 - val_loss: 0.1896 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 435/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.3453 - categorical_accuracy: 0.8706 - val_loss: 0.2078 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 436/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2815 - categorical_accuracy: 0.9176 - val_loss: 0.1918 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 437/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3426 - categorical_accuracy: 0.9000 - val_loss: 0.1886 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 438/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.2705 - categorical_accuracy: 0.9176 - val_loss: 0.1903 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 439/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.1864 - categorical_accuracy: 0.9529 - val_loss: 0.1865 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 440/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.3170 - categorical_accuracy: 0.8824 - val_loss: 0.1778 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 441/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.2651 - categorical_accuracy: 0.9000 - val_loss: 0.1826 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 442/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2802 - categorical_accuracy: 0.9294 - val_loss: 0.1704 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 443/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2867 - categorical_accuracy: 0.9176 - val_loss: 0.2025 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 444/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2223 - categorical_accuracy: 0.9529 - val_loss: 0.1956 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 445/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3554 - categorical_accuracy: 0.8882 - val_loss: 0.1830 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 446/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.3075 - categorical_accuracy: 0.8824 - val_loss: 0.1985 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 447/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2663 - categorical_accuracy: 0.9353 - val_loss: 0.2027 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 448/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3301 - categorical_accuracy: 0.9000 - val_loss: 0.1902 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 449/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2803 - categorical_accuracy: 0.9235 - val_loss: 0.1941 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 450/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3122 - categorical_accuracy: 0.9118 - val_loss: 0.2160 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 451/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2648 - categorical_accuracy: 0.9059 - val_loss: 0.2022 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 452/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2859 - categorical_accuracy: 0.9059 - val_loss: 0.1859 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 453/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3581 - categorical_accuracy: 0.9118 - val_loss: 0.1883 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 454/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2376 - categorical_accuracy: 0.9235 - val_loss: 0.2016 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 455/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2809 - categorical_accuracy: 0.9059 - val_loss: 0.1794 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 456/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2530 - categorical_accuracy: 0.9118 - val_loss: 0.1747 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 457/500
# 15/15 [==============================] - 0s 31ms/step - loss: 0.3039 - categorical_accuracy: 0.9176 - val_loss: 0.1824 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 458/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.1965 - categorical_accuracy: 0.9412 - val_loss: 0.2169 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 459/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2247 - categorical_accuracy: 0.9471 - val_loss: 0.2014 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 460/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2529 - categorical_accuracy: 0.8941 - val_loss: 0.1884 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 461/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2780 - categorical_accuracy: 0.9118 - val_loss: 0.1937 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 462/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.3638 - categorical_accuracy: 0.8647 - val_loss: 0.1712 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 463/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3281 - categorical_accuracy: 0.9000 - val_loss: 0.1939 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 464/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3856 - categorical_accuracy: 0.8765 - val_loss: 0.2008 - val_categorical_accuracy: 0.9062 - lr: 4.5000e-05
# Epoch 465/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.3100 - categorical_accuracy: 0.9176 - val_loss: 0.2127 - val_categorical_accuracy: 0.8750 - lr: 4.5000e-05
# Epoch 466/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2841 - categorical_accuracy: 0.8941 - val_loss: 0.1869 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 467/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2577 - categorical_accuracy: 0.9412 - val_loss: 0.1705 - val_categorical_accuracy: 0.9375 - lr: 4.5000e-05
# Epoch 468/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2730 - categorical_accuracy: 0.9235 - val_loss: 0.1693 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 469/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2694 - categorical_accuracy: 0.9176 - val_loss: 0.1704 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 470/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2926 - categorical_accuracy: 0.9059 - val_loss: 0.1701 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 471/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2339 - categorical_accuracy: 0.9235 - val_loss: 0.1813 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 472/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.2656 - categorical_accuracy: 0.9235 - val_loss: 0.1863 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 473/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2687 - categorical_accuracy: 0.9176 - val_loss: 0.1700 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 474/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2570 - categorical_accuracy: 0.9000 - val_loss: 0.1685 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 475/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2636 - categorical_accuracy: 0.8941 - val_loss: 0.1761 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 476/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3084 - categorical_accuracy: 0.8882 - val_loss: 0.1745 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 477/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2582 - categorical_accuracy: 0.9176 - val_loss: 0.1749 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 478/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2706 - categorical_accuracy: 0.9059 - val_loss: 0.1728 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 479/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2491 - categorical_accuracy: 0.9235 - val_loss: 0.1833 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 480/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2476 - categorical_accuracy: 0.9235 - val_loss: 0.1803 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 481/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2921 - categorical_accuracy: 0.9176 - val_loss: 0.1724 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 482/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.3118 - categorical_accuracy: 0.9235 - val_loss: 0.1716 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 483/500
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2340 - categorical_accuracy: 0.9412 - val_loss: 0.1707 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 484/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2501 - categorical_accuracy: 0.9000 - val_loss: 0.1805 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 485/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2102 - categorical_accuracy: 0.9471 - val_loss: 0.1923 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 486/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2209 - categorical_accuracy: 0.9176 - val_loss: 0.1823 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 487/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2315 - categorical_accuracy: 0.9176 - val_loss: 0.1980 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 488/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.3102 - categorical_accuracy: 0.9118 - val_loss: 0.1875 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 489/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.2509 - categorical_accuracy: 0.8941 - val_loss: 0.1660 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 490/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.3041 - categorical_accuracy: 0.8941 - val_loss: 0.1673 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 491/500
# 15/15 [==============================] - 0s 27ms/step - loss: 0.2425 - categorical_accuracy: 0.9118 - val_loss: 0.1681 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 492/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2387 - categorical_accuracy: 0.9118 - val_loss: 0.1832 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 493/500
# 15/15 [==============================] - 0s 29ms/step - loss: 0.2671 - categorical_accuracy: 0.9118 - val_loss: 0.2109 - val_categorical_accuracy: 0.8750 - lr: 2.2500e-05
# Epoch 494/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.2019 - categorical_accuracy: 0.9294 - val_loss: 0.2111 - val_categorical_accuracy: 0.8750 - lr: 2.2500e-05
# Epoch 495/500
# 15/15 [==============================] - 0s 28ms/step - loss: 0.2223 - categorical_accuracy: 0.9353 - val_loss: 0.1988 - val_categorical_accuracy: 0.8750 - lr: 2.2500e-05
# Epoch 496/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2363 - categorical_accuracy: 0.9353 - val_loss: 0.1930 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 497/500
# 15/15 [==============================] - 1s 35ms/step - loss: 0.2512 - categorical_accuracy: 0.8824 - val_loss: 0.1721 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05
# Epoch 498/500
# 15/15 [==============================] - 1s 37ms/step - loss: 0.2382 - categorical_accuracy: 0.9176 - val_loss: 0.1662 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 499/500
# 15/15 [==============================] - 0s 32ms/step - loss: 0.2217 - categorical_accuracy: 0.9235 - val_loss: 0.1644 - val_categorical_accuracy: 0.9375 - lr: 2.2500e-05
# Epoch 500/500
# 15/15 [==============================] - 0s 30ms/step - loss: 0.2761 - categorical_accuracy: 0.9294 - val_loss: 0.1813 - val_categorical_accuracy: 0.9062 - lr: 2.2500e-05

# %%
lstm_model.save('models/lstm_5_classes.ckpt')
# Out:
# INFO:tensorflow:Assets written to: models/lstm_5_classes.ckpt\assets
# 2023-04-17 21:33:56,657 Assets written to: models/lstm_5_classes.ckpt\assets
# 2023-04-17 21:33:56,817 <keras.layers.recurrent.LSTMCell object at 0x0000027969112FD0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 2023-04-17 21:33:56,817 <keras.layers.recurrent.LSTMCell object at 0x000002796910B6D0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 2023-04-17 21:33:56,817 <keras.layers.recurrent.LSTMCell object at 0x0000027969120940> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
path_to_model = os.path.join('models', 'lstm_5_classes.ckpt')

# %%
trained_model = tf.keras.models.load_model(path_to_model)

# %%
import pandas as pd
import matplotlib.pyplot as plt

model_learning_data = pd.read_csv("models/lstm_5_classes.csv")
model_learning_data
# fig, ax = plt.subplots(figsize=(20, 15))
# ax.scatter(x=model_learning_data['epoch'], y=model_learning_data['loss'])
# ax.scatter(x=model_learning_data['epoch'], y=model_learning_data['val_loss'])
# Out:
#      epoch  categorical_accuracy      loss  val_categorical_accuracy  val_loss
# 0        0              0.241176  1.613844                   0.34375  1.612229
# 1        1              0.211765  1.612768                   0.34375  1.610618
# 2        2              0.205882  1.619174                   0.37500  1.609889
# 3        3              0.211765  1.614052                   0.37500  1.609004
# 4        4              0.194118  1.605055                   0.34375  1.607940
# ..     ...                   ...       ...                       ...       ...
# 495    495              0.935294  0.236288                   0.90625  0.193005
# 496    496              0.882353  0.251174                   0.90625  0.172108
# 497    497              0.917647  0.238201                   0.93750  0.166189
# 498    498              0.923529  0.221693                   0.93750  0.164368
# 499    499              0.929412  0.276062                   0.90625  0.181261
#
# [500 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(model_learning_data['epoch'], model_learning_data['loss'])
ax.plot(model_learning_data['epoch'], model_learning_data['val_loss'], color='orange')
plt.show()

# %% [markdown]
# ### **Predictions**

# %%
test_preds = lstm_model.predict(x_test)
train_preds = lstm_model.predict(x_train)
val_preds = lstm_model.predict(x_val)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
accuracy_score(np.argmax(y_train, axis=1), np.argmax(train_preds, axis=1))
# Out:
# 0.9823529411764705

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(val_preds, axis=1))
# Out:
# 0.90625

# %%
accuracy_score(np.argmax(y_test, axis=1), np.argmax(test_preds, axis=1))
# Out:
# 0.9090909090909091

# %%
train_cm = ConfusionMatrixDisplay(confusion_matrix(np.argmax(y_train, axis=1), np.argmax(train_preds, axis=1)))
train_cm.plot()
plt.show()

# %%
val_cm = ConfusionMatrixDisplay(confusion_matrix(np.argmax(y_val, axis=1), np.argmax(val_preds, axis=1)))
val_cm.plot()
plt.show()

# %%
test_cm = ConfusionMatrixDisplay(confusion_matrix(np.argmax(y_test, axis=1), np.argmax(test_preds, axis=1)))
test_cm.plot()
plt.show()

# %%
test_preds_treshold = [1 if pred >= 0.5 else 0 for pred in test_preds]
train_preds_treshold = [1 if pred >= 0.5 else 0 for pred in train_preds]
val_preds_treshold = [1 if pred >= 0.5 else 0 for pred in val_preds]

# %%
def manual_accuracy(predictions, real_values):
    acc = round(sum([1 if pred == real else 0 for pred, real in zip(predictions, real_values)]) / len(real_values), 3)
    return acc

# %%
manual_accuracy(test_preds_treshold, y_test), manual_accuracy(train_preds_treshold, y_train), manual_accuracy(val_preds_treshold, y_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-2adc050577d4> in <module>
# ----> 1 manual_accuracy(test_preds_treshold, y_test), manual_accuracy(train_preds_treshold, y_train), manual_accuracy(val_preds_treshold, y_val)
#
# <ipython-input-61-244c7163bfe7> in manual_accuracy(predictions, real_values)
#       1 def manual_accuracy(predictions, real_values):
# ----> 2     acc = round(sum([1 if pred == real else 0 for pred, real in zip(predictions, real_values)]) / len(real_values), 3)
#       3     return acc
#
# <ipython-input-61-244c7163bfe7> in <listcomp>(.0)
#       1 def manual_accuracy(predictions, real_values):
# ----> 2     acc = round(sum([1 if pred == real else 0 for pred, real in zip(predictions, real_values)]) / len(real_values), 3)
#       3     return acc
#
# c:\Users\Piotr\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in __bool__(self)
#    1132
#    1133   def __bool__(self):
# -> 1134     return bool(self._numpy())
#    1135
#    1136   __nonzero__ = __bool__
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
